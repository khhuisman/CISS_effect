# %% [markdown]
# # General system and one Buttiker lead added.

# %%
import kwant
import math
import cmath
from matplotlib import pyplot as plt
import numpy as np
import tinyarray


from scipy import optimize
import scipy
import time
sigma_0 = tinyarray.array([[1, 0], [0, 1]])
sigma_x = tinyarray.array([[0, 1], [1, 0]])
sigma_y = tinyarray.array([[0, -1j], [1j, 0]])
sigma_z = tinyarray.array([[1, 0], [0, -1]])

# %%
import sys
sys.path.insert(0, 'path_to_modules')

# %%
import CalculateCurrentN

# %% [markdown]
# #### Root finding methods

# %%
import Self_consistency_Buttiker_V_Probe

# %% [markdown]
# ### System

# %%
import GoldLeadsSystem_1Probe

# %%
def func_molecule(nrings,chirality_left):
    
    if chirality_left == True:
        return '[{}]M-Helicene'.format(nrings)
    
    if chirality_left == False:
        return '[{}]P-Helicene'.format(nrings)

# %%
def make_system(B=1, u0 = -5.3,t0 =50,
                     nlayers = 3, xi_d = 0.6, xi_p = 0.006,
                    Txz = 3,Tyz = 3,d_L= 50,
                    txz_left_1=1,tyz_left_1=0,
                    txz_left_2=1,tyz_left_2=1,
                    txz_left_3=0,tyz_left_3=1,
                    plot_left = False,
                    txz_right_1=1,tyz_right_1=0, 
                    txz_right_2=1,tyz_right_2=1,
                    txz_right_3=0,tyz_right_3=1,
                    plot_right = False,
                    nrings =6 ,tvec=3,E_z=0,r=1.4,zstart=0,b=3.6,
                    chirality_left=False,
                    u=-18+9.9 ,delta_e=-12.6,Es=-6.21,I=5,M=1,E1=0,E2=0
                     ):
    
    system = GoldLeadsSystem_1Probe.make_system_toy_1B_right(nlayers, xi_d,xi_p,
                Txz,Tyz, d_L,
                 txz_left_1,tyz_left_1,
                txz_left_2,tyz_left_2,
                txz_left_3,tyz_left_3,
                plot_left,
                txz_right_1,tyz_right_1, 
                txz_right_2,tyz_right_2,
                txz_right_3,tyz_right_3,
                plot_right,
                nrings ,tvec,E_z,r,zstart,b,
                chirality_left,
                u,delta_e,Es,
                B,u0,t0,I,M,E1,E2)
    
    
    
    systemf = system.finalized()
    return systemf

# %% [markdown]
# # Define Systems

# %% [markdown]
# #### Set system parameters

# %%
# chirality_left:
# True = M-helicene
# False = P-helicene

# %%
nleads,B,de,t0,u0,attpos , attposM  ,attposE1 , attposE2 = 3,1,0.052, 50,-5.3,5,1,0,0
nrings,chirality_left = 6, True

# %%
func_molecule(nrings,chirality_left)
# Out:
# '[6]M-Helicene'

# %%
# total number of leads = L,R lead + "# Buttiker Probes"
nleads = 2+1 


#System with positive Magnetization
syst_Sgeom_P = make_system(B= abs(B),t0=t0,u0=u0,
                           nrings=nrings,chirality_left=chirality_left,
                           I=attpos ,
                           M =attposM  ,E1=attposE1 , E2=attposE2)
kwant.plot(syst_Sgeom_P,site_size=0.1,hop_lw=0.1);

#System with negative Magnetization
syst_Sgeom_M = make_system(B= -abs(B),t0=t0,u0=u0,I=attpos,
                           nrings=nrings,chirality_left=chirality_left,
                           M =attposM  ,E1=attposE1 , E2=attposE2)
kwant.plot(syst_Sgeom_M,site_size=0.1,hop_lw=0.1);

# %% [markdown]
# # Bias Window

# %%
# fix voltage and fermi energy
ef     = -5.3
Vmax   = 1.1
V_list = np.linspace(0,Vmax,20) 

Vbar_list = [-V for V in V_list]

# energies in the bias window
de = de
emin, emax = ef - Vmax/2 , ef + Vmax/2
print(emin,emax,de)
# Out:
# -5.85 -4.75 0.052

# %% [markdown]
# # Convergence criterium

# %%
tol = 10**-8

# %% [markdown]
# # Calculate transmissions

# %% [markdown]
# # $T_{ij}(m), T_{ji}(m)$

# %%
energies,list_tags_transmissions_P,list_tags_transmissions_M =  Self_consistency_Buttiker_V_Probe.list_tag_transmission_functions(
                                                                                            nleads=nleads,
                                                                                                systf=syst_Sgeom_P,
                                                                                      emin=emin,emax=emax,de=de)

# %% [markdown]
# # Plot Transmissions

# %% [markdown]
# # $T_{ij}(m), T_{ji}(m)$

# %%
CalculateCurrentN.plot_transmission_i(0,list_tags_transmissions_P,energies)

# %%
CalculateCurrentN.plot_transmission_i(1,list_tags_transmissions_P,energies)

# %%
CalculateCurrentN.plot_transmission_i(2,list_tags_transmissions_P,energies)

# %% [markdown]
# # $\mu(m,+V)$

# %%
muBs_P_sol_list = Self_consistency_Buttiker_V_Probe.muB_selfconsistent(ef,V_list,nleads,list_tags_transmissions_P,
                                         energies,syst_Sgeom_P,
                                          print_bool=True,tol = tol)
# Out:
# --- V = 0.0 ---
# [6.661338147750939e-14]
# [6.661338147750939e-14]
# [6.661338147750939e-14]
# [2.8460547296660366e-07]
# [-0.05334769864120559]
# --- mu2,mu3,... =[-5.3]
# --- V = 0.05789473684210527 ---
# [0.021102940019212424]
# [0.021102940019212424]
# [0.021102940019212424]
# [0.021103224624618777]
# [1.0686672207160797e-06]
# [4.667581876560689e-10]
# [9.992007221626409e-15]
# --- mu2,mu3,... =[-5.30585623]
# --- V = 0.11578947368421054 ---
# [0.03341458870402758]
# [0.03341458870402758]
# [0.03341458870402758]
# [0.033414873485043906]
# [0.0006301859132560317]
# [3.96136371438871e-06]
# [-7.47462536310195e-10]
# [1.7763568394002505e-15]
# --- mu2,mu3,... =[-5.31531253]
# --- V = 0.1736842105263158 ---
# [0.027306777165073903]
# [0.027306777165073903]
# [0.027306777165073903]
# [0.027307055366480704]
# [-0.0001119005518099847]
# [2.2398989552030457e-07]
# [7.580602812140569e-13]
# [-1.3322676295501878e-15]
# --- mu2,mu3,... =[-5.32305514]
# --- V = 0.23157894736842108 ---
# [0.027421971333891904]
# [0.027421971333891904]
# [0.027421971333891904]
# [0.02742225164126655]
# [5.570512221897417e-05]
# [1.3523925950220672e-06]
# [2.7567903515546277e-10]
# [4.884981308350689e-15]
# --- mu2,mu3,... =[-5.33083103]
# --- V = 0.2894736842105263 ---
# [0.019963599206431315]
# [0.019963599206431315]
# [0.019963599206431315]
# [0.0199638724948783]
# [-0.00031629436686775314]
# [2.968199741548716e-07]
# [-1.1008971512183052e-12]
# [-1.1102230246251565e-15]
# --- mu2,mu3,... =[-5.33654335]
# --- V = 0.3473684210526316 ---
# [0.013449086951290434]
# [0.013449086951290434]
# [0.013449086951290434]
# [0.0134493651289187]
# [2.831930606905786e-06]
# [7.642810828656366e-10]
# [1.1102230246251565e-15]
# --- mu2,mu3,... =[-5.34038876]
# --- V = 0.4052631578947369 ---
# [0.009046928411653887]
# [0.009046928411653887]
# [0.009046928411653887]
# [0.009047206655982576]
# [2.2906943069056496e-06]
# [6.483686920688569e-10]
# [1.1102230246251565e-15]
# --- mu2,mu3,... =[-5.34297684]
# --- V = 0.46315789473684216 ---
# [0.01138083514739563]
# [0.01138083514739563]
# [0.01138083514739563]
# [0.011381113377287644]
# [5.024947635767774e-06]
# [2.460712522633912e-09]
# [3.1086244689504383e-15]
# --- mu2,mu3,... =[-5.34623495]
# --- V = 0.5210526315789474 ---
# [0.011838848853998218]
# [0.011838848853998218]
# [0.011838848853998218]
# [0.011839126994294347]
# [7.2408552644898094e-06]
# [4.8101038707670796e-09]
# [6.217248937900877e-15]
# --- mu2,mu3,... =[-5.34962791]
# --- V = 0.5789473684210527 ---
# [0.008384182684322061]
# [0.008384182684322061]
# [0.008384182684322061]
# [0.008384460646033043]
# [4.476765831817886e-06]
# [2.5091841937552317e-09]
# [1.1102230246251565e-15]
# --- mu2,mu3,... =[-5.35203367]
# --- V = 0.636842105263158 ---
# [0.004218280551546716]
# [0.004218280551546716]
# [0.004218280551546716]
# [0.004218558333910938]
# [1.2738726637984144e-06]
# [3.932547620877358e-10]
# [-1.3322676295501878e-15]
# --- mu2,mu3,... =[-5.35324511]
# --- V = 0.6947368421052632 ---
# [-0.003654219232730682]
# [-0.003654219232730682]
# [-0.003654219232730682]
# [-0.003653941557164586]
# [9.805537677376464e-07]
# [-2.5817237236935853e-10]
# [1.7763568394002505e-15]
# --- mu2,mu3,... =[-5.35219562]
# --- V = 0.7526315789473685 ---
# [-0.006018916095572813]
# [-0.006018916095572813]
# [-0.006018916095572813]
# [-0.006018638326845682]
# [2.479177342085137e-06]
# [-9.871845563225179e-10]
# [-4.440892098500626e-15]
# --- mu2,mu3,... =[-5.35046816]
# --- V = 0.8105263157894738 ---
# [-0.005137867925656625]
# [-0.005137867925656625]
# [-0.005137867925656625]
# [-0.005137590021627503]
# [1.6358475867228606e-06]
# [-5.045586171092964e-10]
# [1.5543122344752192e-15]
# --- mu2,mu3,... =[-5.34899462]
# --- V = 0.8684210526315791 ---
# [-0.002116688270399125]
# [-0.002116688270399125]
# [-0.002116688270399125]
# [-0.002116410268746094]
# [2.566853165575367e-07]
# [-3.071676246690913e-11]
# [1.9984014443252818e-14]
# --- mu2,mu3,... =[-5.34838781]
# --- V = 0.9263157894736843 ---
# [0.0018995155869661051]
# [0.0018995155869661051]
# [0.0018995155869661051]
# [0.0018997936240279234]
# [2.034776731552057e-07]
# [2.2075896666251538e-11]
# [2.6645352591003757e-15]
# --- mu2,mu3,... =[-5.34893235]
# --- V = 0.9842105263157895 ---
# [0.004922748633610308]
# [0.004922748633610308]
# [0.004922748633610308]
# [0.004923026639021666]
# [1.446103540470034e-06]
# [4.380205087528566e-10]
# [3.552713678800501e-15]
# --- mu2,mu3,... =[-5.35034414]
# --- V = 1.0421052631578949 ---
# [0.0083925978636743]
# [0.0083925978636743]
# [0.0083925978636743]
# [0.008392875776546127]
# [4.6835959570667995e-06]
# [2.7385760326126274e-09]
# [1.9984014443252818e-15]
# --- mu2,mu3,... =[-5.35275311]
# --- V = 1.1 ---
# [0.010357569301057579]
# [0.010357569301057579]
# [0.010357569301057579]
# [0.010357847021323474]
# [8.224333048589827e-06]
# [6.864647517090816e-09]
# [2.4424906541753444e-15]
# --- mu2,mu3,... =[-5.35573021]

# %%
IP_list_0,IP_list_1, IP_list_2 = Self_consistency_Buttiker_V_Probe.currents_list(muBs_P_sol_list,V_list,
                                             ef,nleads,list_tags_transmissions_P,energies,
                                                                                  syst_Sgeom_P)

# %% [markdown]
# # $\bar{\mu}_B(m,-V) $

# %%
mubarBs_P_sol_list = Self_consistency_Buttiker_V_Probe.muB_selfconsistent(ef,Vbar_list,nleads,list_tags_transmissions_P,
                                        energies,syst_Sgeom_P,
                                          print_bool=True,tol = tol)
# Out:
# --- V = -0.0 ---
# [6.661338147750939e-14]
# [6.661338147750939e-14]
# [6.661338147750939e-14]
# [2.8460547296660366e-07]
# [-0.05334769864120559]
# --- mu2,mu3,... =[-5.3]
# --- V = -0.05789473684210527 ---
# [-0.02181302394405704]
# [-0.02181302394405704]
# [-0.02181302394405704]
# [-0.02181273933865069]
# [1.5148882881010906e-05]
# [8.952483865343197e-09]
# [-1.687538997430238e-14]
# --- mu2,mu3,... =[-5.29395123]
# --- V = -0.11578947368421054 ---
# [-0.032088919618932676]
# [-0.032088919618932676]
# [-0.032088919618932676]
# [-0.03208863530875239]
# [-0.00014435780580890345]
# [-1.059534917358107e-06]
# [-5.0316639743641645e-11]
# [-5.773159728050814e-15]
# --- mu2,mu3,... =[-5.28500716]
# --- V = -0.1736842105263158 ---
# [-0.030975155184015613]
# [-0.030975155184015613]
# [-0.030975155184015613]
# [-0.030974874718314505]
# [-0.00022911552686766257]
# [2.4883150044896496e-06]
# [8.996603462207986e-11]
# [1.5543122344752192e-15]
# --- mu2,mu3,... =[-5.27624544]
# --- V = -0.23157894736842108 ---
# [-0.03284566070217432]
# [-0.03284566070217432]
# [-0.03284566070217432]
# [-0.03284537976413682]
# [-0.00024806518618980533]
# [-2.41587814153732e-06]
# [-2.1112223080876902e-10]
# [0.0]
# --- mu2,mu3,... =[-5.26698275]
# --- V = -0.2894736842105263 ---
# [-0.034212562597831786]
# [-0.034212562597831786]
# [-0.034212562597831786]
# [-0.03421228700597889]
# [-0.0004207797556665671]
# [-4.986025280873108e-06]
# [-6.32270902301002e-10]
# [-1.5543122344752192e-15]
# --- mu2,mu3,... =[-5.25711678]
# --- V = -0.3473684210526316 ---
# [-0.03486366868560409]
# [-0.03486366868560409]
# [-0.03486366868560409]
# [-0.034863400247017395]
# [-0.00022572702642364995]
# [-3.5352427096846384e-07]
# [9.866107930633916e-12]
# [-2.220446049250313e-16]
# --- mu2,mu3,... =[-5.24687627]
# --- V = -0.4052631578947369 ---
# [-0.03656081551370338]
# [-0.03656081551370338]
# [-0.03656081551370338]
# [-0.03656054974209244]
# [0.0016063613050447678]
# [-0.00029502531821767874]
# [1.3197170731782393e-05]
# [1.5000668351916602e-07]
# [-7.047917804925419e-11]
# [1.2034817586936697e-13]
# --- mu2,mu3,... =[-5.23650631]
# --- V = -0.46315789473684216 ---
# [-0.03736277817973721]
# [-0.03736277817973721]
# [-0.03736277817973721]
# [-0.03736243949790663]
# [-0.005529304116887568]
# [-0.00027089361719379035]
# [-1.601258971639652e-06]
# [-4.765752237290144e-10]
# [-6.661338147750939e-16]
# --- mu2,mu3,... =[-5.2263255]
# --- V = -0.5210526315789474 ---
# [-0.03682509576323145]
# [-0.03682509576323145]
# [-0.03682509576323145]
# [-0.03682482357415284]
# [-0.0005598184714050713]
# [-7.108681646217363e-06]
# [-1.405486838024217e-09]
# [4.707345624410664e-14]
# --- mu2,mu3,... =[-5.21562442]
# --- V = -0.5789473684210527 ---
# [-0.03790485802625376]
# [-0.03790485802625376]
# [-0.03790485802625376]
# [-0.03790459397358514]
# [-0.0001552525225734236]
# [9.627028136893756e-07]
# [-5.834621674694063e-11]
# [5.81756864903582e-14]
# --- mu2,mu3,... =[-5.20442225]
# --- V = -0.636842105263158 ---
# [-0.034035413010441884]
# [-0.034035413010441884]
# [-0.034035413010441884]
# [-0.03403514896104043]
# [0.0005301277845839447]
# [-2.447822443563119e-05]
# [5.24440686433536e-08]
# [6.448841460837684e-12]
# --- mu2,mu3,... =[-5.19457253]
# --- V = -0.6947368421052632 ---
# [-0.030526014423812642]
# [-0.030526014423812642]
# [-0.030526014423812642]
# [-0.0305257338452829]
# [-9.63372341395985e-05]
# [9.101698443814144e-07]
# [-2.9442004390034526e-11]
# [-5.551115123125783e-15]
# --- mu2,mu3,... =[-5.18612469]
# --- V = -0.7526315789473685 ---
# [-0.02675328862338411]
# [-0.02675328862338411]
# [-0.02675328862338411]
# [-0.026753006737954443]
# [0.0002311695864714025]
# [-1.8844674902762648e-06]
# [-1.252620229763579e-10]
# [3.375077994860476e-14]
# --- mu2,mu3,... =[-5.17885257]
# --- V = -0.8105263157894738 ---
# [-0.023023740268738546]
# [-0.023023740268738546]
# [-0.023023740268738546]
# [-0.023023454050608017]
# [-9.043071766345889e-05]
# [-2.7689999972935198e-06]
# [8.396083828188239e-11]
# [-8.881784197001252e-16]
# --- mu2,mu3,... =[-5.17261959]
# --- V = -0.8684210526315791 ---
# [-0.019968385557839863]
# [-0.019968385557839863]
# [-0.019968385557839863]
# [-0.019968109517471078]
# [0.000131092897041718]
# [-8.321808726563518e-07]
# [-3.3509195418446325e-11]
# [0.0]
# --- mu2,mu3,... =[-5.16708001]
# --- V = -0.9263157894736843 ---
# [-0.016996045519191316]
# [-0.016996045519191316]
# [-0.016996045519191316]
# [-0.01699576621340304]
# [8.695947790293701e-05]
# [-4.310954406783196e-07]
# [-1.0583089959936842e-11]
# [-4.440892098500626e-15]
# --- mu2,mu3,... =[-5.16241848]
# --- V = -0.9842105263157895 ---
# [-0.016771456823097886]
# [-0.016771456823097886]
# [-0.016771456823097886]
# [-0.016771174957909363]
# [7.747219024745178e-05]
# [-3.4529135595207094e-07]
# [-6.849187883517516e-12]
# [1.7763568394002505e-15]
# --- mu2,mu3,... =[-5.15786221]
# --- V = -1.0421052631578949 ---
# [-0.01602623441745621]
# [-0.01602623441745621]
# [-0.01602623441745621]
# [-0.016025950244807685]
# [6.375684630777201e-05]
# [-2.4341014492890167e-07]
# [-3.538058734875449e-12]
# [0.0]
# --- mu2,mu3,... =[-5.15354482]
# --- V = -1.1 ---
# [-0.017867287892209482]
# [-0.017867287892209482]
# [-0.017867287892209482]
# [-0.01786700174365974]
# [6.951118222220387e-05]
# [-2.5496208833075684e-07]
# [-3.410161042438631e-12]
# [-1.3766765505351941e-14]
# --- mu2,mu3,... =[-5.14876828]

# %%
IPbar_list_0,IPbar_list_1, IPbar_list_2 = Self_consistency_Buttiker_V_Probe.currents_list(mubarBs_P_sol_list,
                                                                                          Vbar_list,
                                             ef,nleads,list_tags_transmissions_P,energies,
                                                                                  syst_Sgeom_P)

# %% [markdown]
# # $\mu_B(-m,+V)$

# %%
muBs_M_sol_list_test = Self_consistency_Buttiker_V_Probe.muB_selfconsistent(ef,V_list,nleads,
                                                                            list_tags_transmissions_M,
                                                                            energies,syst_Sgeom_M,
                                                                          print_bool=False,tol = tol )
# Out:
# --- V = 0.0 ---
# --- mu2,mu3,... =[-5.3]
# --- V = 0.05789473684210527 ---
# --- mu2,mu3,... =[-5.30580769]
# --- V = 0.11578947368421054 ---
# --- mu2,mu3,... =[-5.31522519]
# --- V = 0.1736842105263158 ---
# --- mu2,mu3,... =[-5.32284496]
# --- V = 0.23157894736842108 ---
# --- mu2,mu3,... =[-5.3305937]
# --- V = 0.2894736842105263 ---
# --- mu2,mu3,... =[-5.33632211]
# --- V = 0.3473684210526316 ---
# --- mu2,mu3,... =[-5.34020533]
# --- V = 0.4052631578947369 ---
# --- mu2,mu3,... =[-5.34285014]
# --- V = 0.46315789473684216 ---
# --- mu2,mu3,... =[-5.3461716]
# --- V = 0.5210526315789474 ---
# --- mu2,mu3,... =[-5.34961777]
# --- V = 0.5789473684210527 ---
# --- mu2,mu3,... =[-5.35211218]
# --- V = 0.636842105263158 ---
# --- mu2,mu3,... =[-5.35338689]
# --- V = 0.6947368421052632 ---
# --- mu2,mu3,... =[-5.35238463]
# --- V = 0.7526315789473685 ---
# --- mu2,mu3,... =[-5.35068685]
# --- V = 0.8105263157894738 ---
# --- mu2,mu3,... =[-5.34922687]
# --- V = 0.8684210526315791 ---
# --- mu2,mu3,... =[-5.34862495]
# --- V = 0.9263157894736843 ---
# --- mu2,mu3,... =[-5.34917563]
# --- V = 0.9842105263157895 ---
# --- mu2,mu3,... =[-5.35060212]
# --- V = 1.0421052631578949 ---
# --- mu2,mu3,... =[-5.35304488]
# --- V = 1.1 ---
# --- mu2,mu3,... =[-5.35608795]

# %%
IM_list_0, IM_list_1, IM_list_2 = Self_consistency_Buttiker_V_Probe.currents_list(muBs_M_sol_list_test,V_list,
                                             ef,nleads,list_tags_transmissions_M,energies,
                                                                                  syst_Sgeom_M)

# %% [markdown]
# # $\overline{\mu}_B(-m,-V)$

# %%
mubarBs_M_sol_list_test = Self_consistency_Buttiker_V_Probe.muB_selfconsistent(ef,Vbar_list,nleads,list_tags_transmissions_M,
                                             energies,syst_Sgeom_M,
                                          print_bool=True,tol = tol)
# Out:
# --- V = -0.0 ---
# [-7.771561172376096e-14]
# [-7.771561172376096e-14]
# [-7.771561172376096e-14]
# [2.8460532863761046e-07]
# [-0.053347698641279084]
# --- mu2,mu3,... =[-5.3]
# --- V = -0.05789473684210527 ---
# [-0.021638206949625705]
# [-0.021638206949625705]
# [-0.021638206949625705]
# [-0.02163792234421935]
# [1.5129069557584529e-05]
# [8.674206020131692e-09]
# [-1.021405182655144e-14]
# --- mu2,mu3,... =[-5.29399974]
# --- V = -0.11578947368421054 ---
# [-0.03195701279244312]
# [-0.03195701279244312]
# [-0.03195701279244312]
# [-0.031956728473313545]
# [-0.00014148407538483454]
# [-1.023581515546823e-06]
# [-4.721045776534538e-11]
# [5.995204332975845e-15]
# --- mu2,mu3,... =[-5.28509327]
# --- V = -0.1736842105263158 ---
# [-0.030539138605544913]
# [-0.030539138605544913]
# [-0.030539138605544913]
# [-0.030538858078843045]
# [-0.00023787639089345447]
# [2.685838612626057e-06]
# [9.739853368273543e-11]
# [4.440892098500626e-16]
# --- mu2,mu3,... =[-5.27645328]
# --- V = -0.23157894736842108 ---
# [-0.0327701304566379]
# [-0.0327701304566379]
# [-0.0327701304566379]
# [-0.032769849442551235]
# [-0.00024164021398953572]
# [-2.3149135073285976e-06]
# [-1.9545076668237016e-10]
# [1.5543122344752192e-15]
# --- mu2,mu3,... =[-5.26721571]
# --- V = -0.2894736842105263 ---
# [-0.034256906650419694]
# [-0.034256906650419694]
# [-0.034256906650419694]
# [-0.03425663088794195]
# [-0.0004214633519163957]
# [-5.03533593709804e-06]
# [-6.50912657107483e-10]
# [-3.9968028886505635e-15]
# --- mu2,mu3,... =[-5.25734258]
# --- V = -0.3473684210526316 ---
# [-0.034996246179365365]
# [-0.034996246179365365]
# [-0.034996246179365365]
# [-0.03499597760327644]
# [-0.0002366118151573282]
# [-4.492052656512868e-07]
# [1.2004175431457043e-11]
# [3.552713678800501e-15]
# --- mu2,mu3,... =[-5.24706496]
# --- V = -0.4052631578947369 ---
# [-0.036759396120104926]
# [-0.036759396120104926]
# [-0.036759396120104926]
# [-0.036759130379703686]
# [0.0015245385338988893]
# [-0.00033939287534123785]
# [2.1540513857276622e-05]
# [4.4463636128533324e-07]
# [-5.165177174859537e-10]
# [2.313704783318826e-13]
# --- mu2,mu3,... =[-5.23660649]
# --- V = -0.46315789473684216 ---
# [-0.0375843797608002]
# [-0.0375843797608002]
# [-0.0375843797608002]
# [-0.03758402763097579]
# [-0.006652640122475351]
# [-0.00034208427244553086]
# [-2.4128659121824825e-06]
# [-9.039111681374834e-10]
# [-1.4210854715202004e-14]
# --- mu2,mu3,... =[-5.22638877]
# --- V = -0.5210526315789474 ---
# [-0.037010904631874286]
# [-0.037010904631874286]
# [-0.037010904631874286]
# [-0.03701063230718615]
# [-0.000576281881348395]
# [-7.363661449044656e-06]
# [-1.5005312548055372e-09]
# [-5.551115123125783e-15]
# --- mu2,mu3,... =[-5.21563483]
# --- V = -0.5789473684210527 ---
# [-0.03821366472638621]
# [-0.03821366472638621]
# [-0.03821366472638621]
# [-0.03821340066660017]
# [-0.00015562668515678446]
# [9.909269302887935e-07]
# [-6.058309409695539e-11]
# [2.220446049250313e-15]
# --- mu2,mu3,... =[-5.20434195]
# --- V = -0.636842105263158 ---
# [-0.034255494792014396]
# [-0.034255494792014396]
# [-0.034255494792014396]
# [-0.03425523069008318]
# [0.0005516056224628141]
# [-2.3427078906568255e-05]
# [2.9650867761077393e-08]
# [1.900479773553343e-12]
# --- mu2,mu3,... =[-5.1944361]
# --- V = -0.6947368421052632 ---
# [-0.030690746711431238]
# [-0.030690746711431238]
# [-0.030690746711431238]
# [-0.030690467156769152]
# [2.1247743662078378e-05]
# [-2.062506023747801e-07]
# [-1.468603016974157e-12]
# [-1.7763568394002505e-15]
# --- mu2,mu3,... =[-5.18594427]
# --- V = -0.7526315789473685 ---
# [-0.02685726128018895]
# [-0.02685726128018895]
# [-0.02685726128018895]
# [-0.026856979280217574]
# [0.00023205127201486597]
# [-1.8909567742753097e-06]
# [-1.2559508988374546e-10]
# [5.329070518200751e-15]
# --- mu2,mu3,... =[-5.1786471]
# --- V = -0.8105263157894738 ---
# [-0.023071518358867005]
# [-0.023071518358867005]
# [-0.023071518358867005]
# [-0.023071232026869337]
# [-0.00012804397555310487]
# [-3.706814347470555e-06]
# [1.5862067215266507e-10]
# [-1.7763568394002505e-15]
# --- mu2,mu3,... =[-5.17239347]
# --- V = -0.8684210526315791 ---
# [-0.019985644529627145]
# [-0.019985644529627145]
# [-0.019985644529627145]
# [-0.019985368351620014]
# [0.000130856948030722]
# [-8.283445405155021e-07]
# [-3.3165026280812526e-11]
# [-1.3322676295501878e-15]
# --- mu2,mu3,... =[-5.16685201]
# --- V = -0.9263157894736843 ---
# [-0.01701728014822912]
# [-0.01701728014822912]
# [-0.01701728014822912]
# [-0.017017000713038133]
# [8.68223105428001e-05]
# [-4.291067341455346e-07]
# [-1.0468959033005376e-11]
# [0.0]
# --- mu2,mu3,... =[-5.16218697]
# --- V = -0.9842105263157895 ---
# [-0.016822167935065746]
# [-0.016822167935065746]
# [-0.016822167935065746]
# [-0.01682188594774159]
# [7.755862432823335e-05]
# [-3.4487184130682635e-07]
# [-6.8056671409522096e-12]
# [-1.3322676295501878e-15]
# --- mu2,mu3,... =[-5.15761906]
# --- V = -1.0421052631578949 ---
# [-0.016142822492960285]
# [-0.016142822492960285]
# [-0.016142822492960285]
# [-0.016142538203224532]
# [6.426590712083069e-05]
# [-2.453246046307811e-07]
# [-3.567812711935403e-12]
# [4.440892098500626e-16]
# --- mu2,mu3,... =[-5.15327227]
# --- V = -1.1 ---
# [-0.01809491026618293]
# [-0.01809491026618293]
# [-0.01809491026618293]
# [-0.018094624000708492]
# [7.059351390159563e-05]
# [-2.5916704515793754e-07]
# [-3.47633033470629e-12]
# [5.329070518200751e-15]
# --- mu2,mu3,... =[-5.14843716]

# %%
IMbar_list_0,IMbar_list_1, IMbar_list_2 = Self_consistency_Buttiker_V_Probe.currents_list(mubarBs_M_sol_list_test,
                                                                                          Vbar_list,
                                                     ef,nleads,list_tags_transmissions_M,energies,
                                                                                  syst_Sgeom_M)

# %% [markdown]
# # $ \Delta I, MR(V)$

# %%
dIlist    = np.subtract(IP_list_0,IM_list_0)
dIbarlist = np.subtract(IPbar_list_0,IMbar_list_0)


MR_list    = Self_consistency_Buttiker_V_Probe.calc_MR_list(IP_list_0,IM_list_0,V_list)
MRbar_list = Self_consistency_Buttiker_V_Probe.calc_MR_list(IPbar_list_0,IMbar_list_0,Vbar_list)

# %% [markdown]
# # Check that $I_B =0$

# %%
plt.plot(V_list,IM_list_2,label='IB(-m)')
plt.plot(Vbar_list,IMbar_list_2,label='IbarB(-m)')

plt.plot(V_list,IP_list_2,label='IB(+m)')
plt.plot(Vbar_list,IPbar_list_2,label='IbarB(+m)')



plt.xlabel('Voltage ')
plt.ylabel('Charged Current ')
plt.legend()


plt.show()

plt.title('$\Delta I (m)$')
plt.plot(V_list,dIlist)
plt.plot(Vbar_list,dIbarlist)



plt.xlabel('Voltage ')
plt.ylabel('Charged Current ')
# plt.legend()


plt.show()
# Out:
# <>:16: DeprecationWarning: invalid escape sequence \D
# <>:16: DeprecationWarning: invalid escape sequence \D
# <>:16: DeprecationWarning: invalid escape sequence \D
# <ipython-input-44-4817fa89b405>:16: DeprecationWarning: invalid escape sequence \D
#   plt.title('$\Delta I (m)$')

# %% [markdown]
# # Fig 4A : MR

# %%
plt.plot(V_list,MR_list,color='red',label = '{}'.format(func_molecule(nrings,chirality_left)))



# Plot labels
plt.xlabel('Bias Voltage [eV] ')
plt.ylabel('MR [%] ')
plt.legend()



plt.show()

# %% [markdown]
# # Fig 4b : $\Delta I$ : Even,Odd

# %%
DP_list = np.subtract(IP_list_0,IPbar_list_0)
DM_list = np.subtract(IM_list_0,IMbar_list_0)

# %%
RP_list = np.add(IP_list_0,IPbar_list_0)
RM_list = np.add(IM_list_0,IMbar_list_0)

# %%
dIList = np.add(
                np.subtract(DP_list,DM_list),
                np.subtract(RP_list,RM_list))

# %%
plt.plot(V_list,np.multiply(0.5,dIList),label="$ \Delta \ I$: total",color='orange')

plt.plot(V_list,np.multiply(0.5,np.subtract(DP_list,DM_list)),label='$ \Delta \ I$: odd',color='red')

plt.plot(V_list,np.multiply(0.5,np.subtract(RP_list,RM_list)),label='$ \Delta \ I$: even', color = 'blue')







# plt.xlabel('Bias Voltage [eV] ')
# plt.ylabel('Current [eV] ')
plt.legend()
plt.ticklabel_format(axis="y", style="sci", scilimits=(0,0))




plt.show()
# Out:
# <>:1: DeprecationWarning: invalid escape sequence \D
# <>:3: DeprecationWarning: invalid escape sequence \D
# <>:5: DeprecationWarning: invalid escape sequence \D
# <>:1: DeprecationWarning: invalid escape sequence \D
# <>:3: DeprecationWarning: invalid escape sequence \D
# <>:5: DeprecationWarning: invalid escape sequence \D
# <>:1: DeprecationWarning: invalid escape sequence \D
# <>:3: DeprecationWarning: invalid escape sequence \D
# <>:5: DeprecationWarning: invalid escape sequence \D
# <ipython-input-49-eb96dcc1c2fe>:1: DeprecationWarning: invalid escape sequence \D
#   plt.plot(V_list,np.multiply(0.5,dIList),label="$ \Delta \ I$: total",color='orange')
# <ipython-input-49-eb96dcc1c2fe>:3: DeprecationWarning: invalid escape sequence \D
#   plt.plot(V_list,np.multiply(0.5,np.subtract(DP_list,DM_list)),label='$ \Delta \ I$: odd',color='red')
# <ipython-input-49-eb96dcc1c2fe>:5: DeprecationWarning: invalid escape sequence \D
#   plt.plot(V_list,np.multiply(0.5,np.subtract(RP_list,RM_list)),label='$ \Delta \ I$: even', color = 'blue')
